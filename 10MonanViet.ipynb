# %%
pip install mtcnn
# Out:
# ...
#      |████████████████████████████████| 2.3 MB 5.1 MB/s
# ...

# %%
import keras
import matplotlib.pyplot as plt
from mtcnn import MTCNN
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/AI/Food/Comtam/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'Comtam'+ str(i) +'.jpg'
  image = plt.imread(filename)
  plt.imshow(image)
plt.show()
folder1 = '/content/drive/MyDrive/AI/Food/Banhmi/'
folder2 = '/content/drive/MyDrive/AI/Food/Pho/'
folder3 = '/content/drive/MyDrive/AI/Food/Banhxeo/'
folder4 = '/content/drive/MyDrive/AI/Food/Banhhoi/'
folder5 = '/content/drive/MyDrive/AI/Food/Chaolong/'
folder6 = '/content/drive/MyDrive/AI/Food/Goicuon/'
folder7 = '/content/drive/MyDrive/AI/Food/Banhtrung/'
folder8 = '/content/drive/MyDrive/AI/Food/Chuoichien/'
folder9 = '/content/drive/MyDrive/AI/Food/Comtam/'
folder10 = '/content/drive/MyDrive/AI/Food/Banhtet/'
photos, labels = list(), list()
for file in listdir(folder1):
  if file.startswith('Banhmi'):
    output = 0
    photo = load_img(folder1+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder2):
  if file.startswith('Pho'):
    output = 1
    photo = load_img(folder2+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder3):
  if file.startswith('Banhxeo'):
    output = 2
    photo = load_img(folder3+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder4):
  if file.startswith('Banhhoi'):
    output = 3
    photo = load_img(folder4+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder5):
  if file.startswith('Chaolong'):
    output = 4
    photo = load_img(folder5+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder6):
  if file.startswith('Goicuon'):
    output = 5
    photo = load_img(folder6+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder7):
  if file.startswith('Banhtrung'):
    output = 6
    photo = load_img(folder7+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder8):
  if file.startswith('Chuoichien'):
    output = 7
    photo = load_img(folder8+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder9):
  if file.startswith('Comtam'):
    output = 8
    photo = load_img(folder9+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder10):
  if file.startswith('Banhtet'):
    output = 9
    photo = load_img(folder10+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
    
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=20, verbose=1)
model.save('10Foods.h5')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (100, 200, 200, 3) (100,)
# Epoch 1/20
# 2/2 [==============================] - 1s 76ms/step - loss: 1084.2025 - accuracy: 0.0600
# Epoch 2/20
# 2/2 [==============================] - 0s 57ms/step - loss: 3355.2905 - accuracy: 0.1000
# Epoch 3/20
# 2/2 [==============================] - 0s 54ms/step - loss: 593.4834 - accuracy: 0.1200
# Epoch 4/20
# 2/2 [==============================] - 0s 56ms/step - loss: 300.2450 - accuracy: 0.1100
# Epoch 5/20
# 2/2 [==============================] - 0s 56ms/step - loss: 110.5180 - accuracy: 0.1100
# Epoch 6/20
# 2/2 [==============================] - 0s 57ms/step - loss: 24.5901 - accuracy: 0.1900
# Epoch 7/20
# 2/2 [==============================] - 0s 55ms/step - loss: 3.8189 - accuracy: 0.2300
# Epoch 8/20
# 2/2 [==============================] - 0s 65ms/step - loss: 2.5645 - accuracy: 0.2200
# Epoch 9/20
# ...

# %%
classes = ["BanhMi","Phobo","BanhXeo","BanhHoi","ChaoLong","GoiCuon","BanhTrung","ChuoiChien","ComTam", "BanhTet"]
img = load_img('/content/drive/MyDrive/AI/Food/Goicuon/Goicuon2.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.10009044 0.0976128  0.10110447 0.1002114  0.096846   0.10631762
#   0.0981366  0.10310733 0.09748875 0.09908458]]
# 'GoiCuon'

# %%
classes = ["BanhMi","Phobo","BanhXeo","BanhHoi","ChaoLong","GoiCuon","BanhTrung","ChuoiChien","ComTam", "BanhTet"]
img = load_img('test6.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255

y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.09685816 0.09786332 0.10029444 0.10249325 0.10075806 0.09954678
#   0.09815899 0.10510042 0.09994891 0.09897772]]
# 'ChuoiChien'

# %%
from keras.preprocessing.image   import load_img
from keras.preprocessing.image  import img_to_array
from keras.models               import load_model
import numpy as np
import matplotlib.pyplot as plt

img = load_img('test6.jpg', target_size=(200, 200))
img = img_to_array(img)
img = img.reshape(1, 200, 200, 3)
img = img.astype('float32')
img = img / 255.0

# load model
#model = load_model('10foods.h5')
# predict the class
result = model.predict(img)
print('Giá trị dự đoán:', np.argmax(result))
plt.show()
# Out:
# Giá trị dự đoán: 7
