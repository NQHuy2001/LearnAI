# %% [markdown]
# <a href="https://colab.research.google.com/github/NQHuy2001/LearnAI/blob/main/HuyWood15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Mun_soc/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+str(i+38810)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder0 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Mun_soc/'
folder1 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Muong_den/'
folder2 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Po_mu/'
folder3 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Que/'
folder4 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Sa_moc_dau/'
folder5 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Sen_mat/'
folder6 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Soi/'
folder7 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Soi_do/'
folder8 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Tau_mat/'
folder9 = '/content/drive/MyDrive/Colab Notebooks/Wood/train/Thuy_tung/'
folder10= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Trai_li/'
folder11= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Tram_hong/'
folder12= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Xa_cu/'
folder13= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Xoan_ta/'
folder14= '/content/drive/MyDrive/Colab Notebooks/Wood/train/Xoay/'

photos, labels = list(), list()
#Mun_soc
for file in listdir(folder0):
    output = 0
    photo = load_img(folder0+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Muong_den
for file in listdir(folder1):
    output = 1
    photo = load_img(folder1+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Po_mu
for file in listdir(folder2):
    output = 2
    photo = load_img(folder2+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Que
for file in listdir(folder3):
    output = 3
    photo = load_img(folder3+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Sa_moc_dau
for file in listdir(folder4):
    output = 4
    photo = load_img(folder4+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Sen_mat
for file in listdir(folder5):
    output = 5
    photo = load_img(folder5+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Soi
for file in listdir(folder6):
    output = 6
    photo = load_img(folder6+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Soi_do
for file in listdir(folder7):
    output = 7
    photo = load_img(folder7+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Tau_mat
for file in listdir(folder8):
    output = 8
    photo = load_img(folder8+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Thuy_tung
for file in listdir(folder9):
    output = 9
    photo = load_img(folder9+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Trai_li
for file in listdir(folder10):
    output = 10
    photo = load_img(folder10+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Tram_hong
for file in listdir(folder11):
    output = 11
    photo = load_img(folder11+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Xa_cu
for file in listdir(folder12):
    output = 12
    photo = load_img(folder12+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Xoan_ta
for file in listdir(folder13):
    output = 13
    photo = load_img(folder13+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)
#Xoay
for file in listdir(folder14):
    output = 14
    photo = load_img(folder14+file,target_size=(100,100))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('15wood_photos.npy', photos)
save('15wood_labels.npy', labels)
# Out:
# (6743, 100, 100, 3) (6743,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(100,100,3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(15, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 100, 100, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 64)                1179712
#
#  dense_1 (Dense)             (None, 15)                975
#
# ...
# Total params: 1,273,935
# Trainable params: 1,273,935
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels,epochs=70, verbose=1)

model.evaluate(photos,labels)
model.save('15wood_Final.h5')
# Out:
# Epoch 1/70
# 211/211 [==============================] - 147s 690ms/step - loss: 57.1497 - accuracy: 0.0750
# Epoch 2/70
# 211/211 [==============================] - 148s 700ms/step - loss: 2.7046 - accuracy: 0.0798
# Epoch 3/70
# 211/211 [==============================] - 146s 691ms/step - loss: 2.7029 - accuracy: 0.0798
# Epoch 4/70
# 211/211 [==============================] - 147s 695ms/step - loss: 2.7018 - accuracy: 0.0798
# Epoch 5/70
# 211/211 [==============================] - 143s 679ms/step - loss: 2.7011 - accuracy: 0.0798
# Epoch 6/70
# 211/211 [==============================] - 148s 703ms/step - loss: 2.7006 - accuracy: 0.0798
# Epoch 7/70
# 211/211 [==============================] - 143s 676ms/step - loss: 2.7003 - accuracy: 0.0798
# Epoch 8/70
# 211/211 [==============================] - 147s 695ms/step - loss: 2.7002 - accuracy: 0.0798
# Epoch 9/70
# 211/211 [==============================] - 146s 691ms/step - loss: 2.7001 - accuracy: 0.0798
# Epoch 10/70
# ...

# %%
#model.evaluate(photos,labels)
#model.save('15wood_Final.h5')
# Out:
# 211/211 [==============================] - 75s 352ms/step - loss: 2.6997 - accuracy: 0.0798

# %%
from keras.models import load_model
models=load_model('15wood_Final.h5')

# %%
classes = ["Mun_soc","Muong_den","Po_mu","Que","Sa_moc_dau","Sen_mat","Soi","Soi_do","Tau_mat","Thuy_tung","Trai_li", "Tram_hong","Xa_cu","Xoan_ta","Xoay"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
#test Go Sa_moc_dau
img = load_img('47839.jpg', target_size=(100,100))
plt.imshow(img)

import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,100,100,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.07429479 0.05188231 0.07290366 0.06913429 0.07961556 0.05279208
#   0.07135523 0.0690975  0.06738051 0.06624101 0.07179918 0.05027496
#   0.07037168 0.07177428 0.06108298]]
# 'Sa_moc_dau'

# %%
#test Go Soi_do
img = load_img('47844.jpg', target_size=(150,150))
imgRe = img_to_array(img)
plt.imshow(img)
imgRe = imgRe.reshape(1,150,150,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.07397868 0.0518712  0.07291763 0.06904903 0.07979234 0.05266398
#   0.07162226 0.06907889 0.06743117 0.06632872 0.07155194 0.05068273
#   0.07039433 0.0713992  0.06123792]]
# 'Sa_moc_dau'

# %%
#test Go Soi
img = load_img('47996.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.11160564 0.09299657 0.08759126 0.08522853 0.09763394 0.09275229
#   0.1328818  0.11657312 0.0849662  0.09777058]]
# 'Soi'

# %%
#test Go Soi
img = load_img('48813.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.13264178 0.08909743 0.07968506 0.1102597  0.10888214 0.08201544
#   0.10304175 0.09438245 0.10077111 0.09922311]]
# 'Mun_soc'
